# %%
List_of_people = {"Ray Grabanski":{"Employer":"Progressive Ag", "Title": "Head Analyst and Trader","Phone":"701-730-2665", "Fun Fact":"I broke my nose batting in high school","Website":"http://www.progressiveag.com/ray-grabanski"},
          
                  "Brian Strommen":{"Employer":"Progressive Ag", "Title": "Broker","Phone":"N/A", "Fun Fact":"Raises Cattle","Website":"http://www.progressiveag.com/staff-detail.aspx?directory_person_id=4"},
                  "Alex Ganenco":{"Employer":"DGI", "Title": "Financial Analyst","Phone":"N/A", "Fun Fact":"Loves to watch reality TV show 'Alone'","Website":"https://dginv.com/alex-ganenco/"},
                  "Joe Neadeau":{"Employer":"DGI", "Title": "Financial Analyst","Phone":"N/A", "Fun Fact":"Was a bouncer for a night club for 5 years","Website":"https://www.linkedin.com/in/joseph-neadeau-97670b86/"},
                                    "Antonio H":{"Employer":"Freelance Contractor", "Title": "Business Consultant","Phone":"N/A", "Fun Fact":"Loves hot tubs","Website":"N/A"},
                                    "Lee Vetsch":{"Employer":"Ospraie Ag Science", "Title": "Venture Capital Analyst","Phone":"N/A", "Fun Fact":"Can make a DCF with one hand","Website":"https://www.linkedin.com/in/lee-vetsch-6b7900130/"},
                                    "Charles Buckhouse":{"Employer":"Corporate Technologies", "Title": "Sr. System Lead Engineer","Phone":"701-212-9940", "Fun Fact":"Likes Geckos","Website":"https://www.linkedin.com/in/charles-buckhouse-55028b54/"},
                                    "Dylan Kallman":{"Employer":"Self-Employed", "Title": "Partner","Phone":"651-200-9578", "Fun Fact":"Jimmy John's is my best friend","Website":"https://www.linkedin.com/in/dylan-kallman-03693b151/"},
                                    "Jacob Radke":{"Employer":"Fjell Capital", "Title": "Analyst","Phone":"218-821-7654", "Fun Fact":"Podcasts and marketing is the future","Website":"https://www.fjellcapital.com/biography/jacob-radke"},
                                    "Mason Anderson":{"Employer":"Thoreson Steffes", "Title": "Portfolio Manager","Phone":"701-478-3342", "Fun Fact":"Huge Bison Fan","Website":""},
                  "Bryce Grabanski":{"Employer":"DGI", "Title": "Summer Analyst","Phone":"701-799-3525", "Fun Fact":"I code for fun in James Caton's Class","Website":""}
                 }
List_of_people
# Out:
# {'Ray Grabanski': {'Employer': 'Progressive Ag',
#   'Title': 'Head Analyst and Trader',
#   'Phone': '701-730-2665',
#   'Fun Fact': 'I broke my nose batting in high school'},
#  'Brian Strommen': {'Employer': 'Progressive Ag',
#   'Title': 'Broker',
#   'Phone': 'N/A',
#   'Fun Fact': 'Raises Cattle'},
#  'Alex Ganenco': {'Employer': 'DGI',
#   'Title': 'Analyst',
#   'Phone': 'N/A',
#   'Fun Fact': "Loves to watch reality TV show 'Alone'"},
#  'Joe Neadeau': {'Employer': 'DGI',
#   'Title': 'Analyst',
#   'Phone': 'N/A',
#   'Fun Fact': 'Was a bouncer for a night club for 5 years'},
#  'Antonio H': {'Employer': 'Freelance Contractor',
#   'Title': 'Business Consultant',
#   'Phone': 'N/A',
#   'Fun Fact': 'Loves hot tubs'},
#  'Lee Vetsch': {'Employer': 'Ospraie Ag Science',
#   'Title': 'Analyst',
#   'Phone': 'N/A',
#   'Fun Fact': 'Can make a DCF with one hand'},
#  'Charles Buckhouse': {'Employer': 'Corporate Technologies',
#   'Title': 'Service Manager',
# ...

# %%
import pandas as pd
List_ = pd.DataFrame(List_of_people).T

# %%
List_
# Out:
#                                  Employer                    Title  \
# Ray Grabanski              Progressive Ag  Head Analyst and Trader
# Brian Strommen             Progressive Ag                   Broker
# Alex Ganenco                          DGI                  Analyst
# Joe Neadeau                           DGI                  Analyst
# Antonio H            Freelance Contractor      Business Consultant
# Lee Vetsch             Ospraie Ag Science                  Analyst
# Charles Buckhouse  Corporate Technologies          Service Manager
# Dylan Kallman               Self-Employed                  Partner
# Jacob Radke                 Fjell Capital                  Analyst
# Mason Anderson           Thoreson Steffes        Portfolio Manager
# Bryce Grabanski                       DGI           Summer Analyst
#
#                           Phone                                    Fun Fact
# Ray Grabanski      701-730-2665      I broke my nose batting in high school
# ...
